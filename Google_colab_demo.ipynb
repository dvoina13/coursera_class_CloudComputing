# %% [markdown]
# <a href="https://colab.research.google.com/github/dvoina13/coursera_class_CloudComputing/blob/main/Google_colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #This is an example Google Colab file as part of the Coursera class

# %%
def hello_world():
  print("useless demo")
